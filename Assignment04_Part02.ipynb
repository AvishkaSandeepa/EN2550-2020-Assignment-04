# %% [markdown]
# # Part 02

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()
print('x_train:', x_train.shape)
K = len(np.unique(y_train)) # Return the unique elements of a tratining output set and take it length as Classes
Ntr = x_train.shape[0] # number of training examples
Nte = x_test.shape[0] # number of testing examples
Din = 3072 # By CIFAR10 data set with 32 x 32 x 3 color images

x_train = x_train[range(Ntr), :]
x_test = x_test[range(Nte), :]
y_train = y_train[range(Ntr)]
y_test = y_test[range(Nte)]


y_train = tf.keras.utils.to_categorical(y_train, num_classes=K) # This function returns a matrix of binary values (either ‘1’ or ‘0’). It has number of rows equal to the length of the input vector and number of columns equal to the number of classes.
y_test = tf.keras.utils.to_categorical(y_test, num_classes=K)
x_train = np.reshape(x_train,(Ntr,Din)).astype('float32') # reshape the data set
x_test = np.reshape(x_test,(Nte,Din)).astype('float32')

#x_train, x_test = x_train / 255.0, x_test / 255.0
mean_image = np.mean(x_train, axis=0)
x_train = x_train - mean_image
x_test = x_test - mean_image

H = 200 # No of hidden nodes
std=1e-6 # standard deviation (sigma)
w1 = std*np.random.randn(Din, H) #Return a sample (or samples) from the “standard normal” distribution.
w2 = std*np.random.randn(H, K)
b1 = np.zeros(H) # creating array of zeros
b2 = np.zeros(K)
print("w1:", w1.shape)
print("w2:", w2.shape)
print("b1:", b1.shape)
print("b2:", b2.shape)
# Out:
# x_train: (50000, 32, 32, 3)
# w1: (3072, 200)
# w2: (200, 10)
# b1: (200,)
# b2: (10,)

# %%
batch_size = Ntr # for gradient descent optimization batch size is equal to number of training set

iterations = round(Ntr/batch_size)*300 # epochs
lr = 1.4e-2 # the learning rate alpha
lr_decay = 0.999
reg = 5e-6 # the regularization constant
loss_history = []
train_acc_history = []
val_acc_history = []
lr_history = []

for t in range(iterations):
    batch_indices = np.random.choice(Ntr, batch_size)
    x = x_train[batch_indices]
    y = y_train[batch_indices]
    #----------------------------------------------for train set---------------------------------------------------------------------
    h = 1.0/(1.0 + np.exp(-(x.dot(w1) + b1 ))) # create a activation function (sigmoid function)
    y_pred = h.dot(w2) + b2 # create predictable output
    #----------------------------------------------for test set----------------------------------------------------------------------
    h_t = 1.0/(1.0 + np.exp(-(x_test.dot(w1) + b1 ))) # create a activation function for test data (sigmoid function)
    y_pred_test = h_t.dot(w2) + b2 # create predictable output
    #--------------------------------------------------------------------------------------------------------------------------------
    loss = (1./batch_size)*np.square(y_pred - y).sum() + reg*(np.sum(w2*w2) + np.sum(w1*w1)) # loss function with regularization term 
    loss_history.append(loss)
    
    # compute the accuracy as percentage
    training_acc = 100*(1 - (1/(batch_size*K))*(np.abs(np.argmax(y,axis=1) - np.argmax(y_pred,axis=1))).sum())  
    testing_acc = 100*(1 - (1/(Nte*K))*(np.abs(np.argmax(y_test,axis=1) - np.argmax(y_pred_test,axis=1))).sum())
    train_acc_history.append(training_acc)
    val_acc_history.append(testing_acc)
    
    if t % 10 == 0:
        print("iteration %d / %d| loss %f| training accuracy %f| testing accuracy %f" % (t, iterations, loss, training_acc, testing_acc))

    dy_pred = 1./batch_size*2.0*(y_pred - y) # partial derivatives w.r.t y_predicted
    dw2 = h.T.dot(dy_pred) + reg*w2
    db2 = dy_pred.sum(axis=0)
    dh = dy_pred.dot(w2.T)
    dw1 = x.T.dot(dh*h*(1-h)) + reg*w1
    db1 = (dh*h*(1-h)).sum(axis=0)
    
    # updating learning parameters
    w1 -= lr*dw1
    w2 -= lr*dw2
    b1 -= lr*db1
    b2 -= lr*db2
    lr *= lr_decay
    
    lr_history.append(lr)
# Out:
# iteration 0 / 300| loss 0.999994| training accuracy 54.895000| testing accuracy 55.000000
# iteration 10 / 300| loss 0.888312| training accuracy 66.619400| testing accuracy 66.342000
# iteration 20 / 300| loss 0.845193| training accuracy 72.107400| testing accuracy 72.163000
# iteration 30 / 300| loss 0.835710| training accuracy 72.152600| testing accuracy 72.551000
# iteration 40 / 300| loss 0.822261| training accuracy 74.181600| testing accuracy 74.266000
# iteration 50 / 300| loss 0.818969| training accuracy 74.378000| testing accuracy 74.649000
# iteration 60 / 300| loss 0.805244| training accuracy 75.938800| testing accuracy 76.085000
# iteration 70 / 300| loss 0.801529| training accuracy 76.569200| testing accuracy 76.515000
# iteration 80 / 300| loss 0.790471| training accuracy 77.337000| testing accuracy 77.354000
# iteration 90 / 300| loss 0.789047| training accuracy 77.363800| testing accuracy 77.474000
# iteration 100 / 300| loss 0.778890| training accuracy 77.725800| testing accuracy 77.686000
# iteration 110 / 300| loss 0.782846| training accuracy 77.568000| testing accuracy 77.522000
# iteration 120 / 300| loss 0.773527| training accuracy 78.122600| testing accuracy 77.999000
# iteration 130 / 300| loss 0.780258| training accuracy 77.413800| testing accuracy 76.510000
# iteration 140 / 300| loss 0.772761| training accuracy 78.325400| testing accuracy 77.721000
# iteration 150 / 300| loss 0.767557| training accuracy 78.303400| testing accuracy 78.045000
# iteration 160 / 300| loss 0.762420| training accuracy 78.693600| testing accuracy 78.187000
# iteration 170 / 300| loss 0.757381| training accuracy 79.101800| testing accuracy 78.480000
# iteration 180 / 300| loss 0.758348| training accuracy 79.109400| testing accuracy 78.406000
# iteration 190 / 300| loss 0.763416| training accuracy 78.946000| testing accuracy 78.220000
# iteration 200 / 300| loss 0.754726| training accuracy 79.013600| testing accuracy 78.626000
# iteration 210 / 300| loss 0.754952| training accuracy 79.485200| testing accuracy 78.800000
# iteration 220 / 300| loss 0.751023| training accuracy 79.659400| testing accuracy 78.738000
# iteration 230 / 300| loss 0.748569| training accuracy 79.014200| testing accuracy 78.296000
# iteration 240 / 300| loss 0.743996| training accuracy 79.773000| testing accuracy 79.022000
# iteration 250 / 300| loss 0.740119| training accuracy 79.534600| testing accuracy 78.511000
# iteration 260 / 300| loss 0.740722| training accuracy 80.175200| testing accuracy 78.644000
# iteration 270 / 300| loss 0.751616| training accuracy 78.527000| testing accuracy 77.388000
# iteration 280 / 300| loss 0.736148| training accuracy 80.040800| testing accuracy 78.799000
# iteration 290 / 300| loss 0.742238| training accuracy 80.290800| testing accuracy 78.658000

# %%
fig, axes = plt.subplots()
axes.plot(loss_history)  
axes.set_xlabel("epochs")
axes.set_ylabel("LOSS")
plt.show()
fig.savefig('LOSS.png',transparent=True)

# %%
fig, axes = plt.subplots() 
axes.plot(train_acc_history)  
axes.set_xlabel("epochs")
axes.set_ylabel("training accuracy")
plt.show()
fig.savefig('training accuracy.png',transparent=True)

# %%
fig, axes = plt.subplots() 
axes.plot(val_acc_history)  
axes.set_xlabel("epochs")
axes.set_ylabel("testing accuracy")
plt.show()
fig.savefig('testing accuracy.png',transparent=True)

# %%
fig, axes = plt.subplots() 
axes.plot(lr_history)  
axes.set_xlabel("epochs")
axes.set_ylabel("learning rate")
plt.show()
fig.savefig('learning rate.png',transparent=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-4481044a7fd3> in <module>
#       1 fig, axes = plt.subplots()
# ----> 2 axes.plot(lr_history)
#       3 axes.set_xlabel("epochs")
#       4 axes.set_ylabel("learning rate")
#       5 plt.show()
#
# NameError: name 'lr_history' is not defined
