# %% [markdown]
# # Part 02

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()
print('x_train:', x_train.shape)
K = len(np.unique(y_train)) # Return the unique elements of a tratining output set and take it length as Classes
Ntr = x_train.shape[0] # number of training examples
Nte = x_test.shape[0] # number of testing examples
Din = 3072 # By CIFAR10 data set with 32 x 32 x 3 color images

x_train = x_train[range(Ntr), :]
x_test = x_test[range(Nte), :]
y_train = y_train[range(Ntr)]
y_test = y_test[range(Nte)]


y_train = tf.keras.utils.to_categorical(y_train, num_classes=K) # This function returns a matrix of binary values (either ‘1’ or ‘0’). It has number of rows equal to the length of the input vector and number of columns equal to the number of classes.
y_test = tf.keras.utils.to_categorical(y_test, num_classes=K)
x_train = np.reshape(x_train,(Ntr,Din)).astype('float32') # reshape the data set
x_test = np.reshape(x_test,(Nte,Din)).astype('float32')

#x_train, x_test = x_train / 255.0, x_test / 255.0
mean_image = np.mean(x_train, axis=0)
x_train = x_train - mean_image
x_test = x_test - mean_image

H = 200 # No of hidden nodes
std=1e-6 # standard deviation (sigma)
w1 = std*np.random.randn(Din, H) #Return a sample (or samples) from the “standard normal” distribution.
w2 = std*np.random.randn(H, K)
b1 = np.zeros(H) # creating array of zeros
b2 = np.zeros(K)
print("w1:", w1.shape)
print("w2:", w2.shape)
print("b1:", b1.shape)
print("b2:", b2.shape)
# Out:
# x_train: (50000, 32, 32, 3)
# w1: (3072, 200)
# w2: (200, 10)
# b1: (200,)
# b2: (10,)

# %%
batch_size = Ntr # for gradient descent optimization batch size is equal to number of training set

iterations = 300 # epochs
lr = 1.4e-2 # the learning rate alpha
lr_decay = 0.999
reg = 5e-6 # the regularization constant
loss_history_test = []
loss_history = []
train_acc_history = []
val_acc_history = []
lr_history = []

# %%
for t in range(iterations):
    batch_indices = np.random.choice(Ntr, batch_size)
    x = x_train[batch_indices]
    y = y_train[batch_indices]
    #forward
    #----------------------------------------------for train set---------------------------------------------------------------------
    h = 1.0/(1.0 + np.exp(-(x.dot(w1) + b1 ))) # create a activation function (sigmoid function)
    y_pred = h.dot(w2) + b2 # create predictable output
    #----------------------------------------------for test set----------------------------------------------------------------------
    h_t = 1.0/(1.0 + np.exp(-(x_test.dot(w1) + b1 ))) # create a activation function for test data (sigmoid function)
    y_pred_test = h_t.dot(w2) + b2 # create predictable output
    #--------------------------------------------------------------------------------------------------------------------------------
    loss_test = (1./Nte)*np.square(y_pred_test - y_test).sum() + reg*(np.sum(w2*w2) + np.sum(w1*w1))
    loss_history_test.append(loss_test)
    loss = (1./batch_size)*np.square(y_pred - y).sum() + reg*(np.sum(w2*w2) + np.sum(w1*w1)) # loss function with regularization term 
    loss_history.append(loss)
    
    # compute the accuracy as percentage
    training_acc = 100*(1 - (1/(batch_size*K))*(np.abs(np.argmax(y,axis=1) - np.argmax(y_pred,axis=1))).sum())  
    testing_acc = 100*(1 - (1/(Nte*K))*(np.abs(np.argmax(y_test,axis=1) - np.argmax(y_pred_test,axis=1))).sum())
    train_acc_history.append(training_acc)
    val_acc_history.append(testing_acc)
    
    if t % 10 == 0:
        print("iteration %d / %d| training loss %f| testing loss %f training accuracy %f| testing accuracy %f" % (t, iterations, loss, loss_test, training_acc, testing_acc))
    
    #backward
    dy_pred = 1./batch_size*2.0*(y_pred - y) # partial derivatives w.r.t y_predicted
    dw2 = h.T.dot(dy_pred) + reg*w2
    db2 = dy_pred.sum(axis=0)
    dh = dy_pred.dot(w2.T)
    dw1 = x.T.dot(dh*h*(1-h)) + reg*w1
    db1 = (dh*h*(1-h)).sum(axis=0)

    # updating learning parameters
    w1 -= lr*dw1
    w2 -= lr*dw2
    b1 -= lr*db1
    b2 -= lr*db2
    lr *= lr_decay
    
    lr_history.append(lr)
# Out:
# iteration 0 / 300| training loss 1.000003| testing loss 1.000003 training accuracy 75.025000| testing accuracy 75.000000
# iteration 10 / 300| training loss 0.968603| testing loss 0.969532 training accuracy 73.073000| testing accuracy 73.000000
# iteration 20 / 300| training loss 0.852416| testing loss 0.852307 training accuracy 72.453200| testing accuracy 72.599000
# iteration 30 / 300| training loss 0.843759| testing loss 0.843805 training accuracy 71.830400| testing accuracy 71.746000
# iteration 40 / 300| training loss 0.833343| testing loss 0.833831 training accuracy 73.686600| testing accuracy 73.577000
# iteration 50 / 300| training loss 0.828945| testing loss 0.829883 training accuracy 73.774200| testing accuracy 73.938000
# iteration 60 / 300| training loss 0.817458| testing loss 0.818683 training accuracy 74.793200| testing accuracy 74.875000
# iteration 70 / 300| training loss 0.809305| testing loss 0.812222 training accuracy 75.540000| testing accuracy 75.672000
# iteration 80 / 300| training loss 0.806297| testing loss 0.808821 training accuracy 75.680200| testing accuracy 75.934000
# iteration 90 / 300| training loss 0.793828| testing loss 0.796934 training accuracy 76.847000| testing accuracy 76.797000
# iteration 100 / 300| training loss 0.803956| testing loss 0.807083 training accuracy 75.748000| testing accuracy 75.793000
# iteration 110 / 300| training loss 0.786717| testing loss 0.788845 training accuracy 77.515000| testing accuracy 77.442000
# iteration 120 / 300| training loss 0.795690| testing loss 0.798542 training accuracy 77.171800| testing accuracy 76.746000
# iteration 130 / 300| training loss 0.784183| testing loss 0.787878 training accuracy 77.751600| testing accuracy 77.077000
# iteration 140 / 300| training loss 0.775137| testing loss 0.781034 training accuracy 77.946000| testing accuracy 77.527000
# iteration 150 / 300| training loss 0.772750| testing loss 0.780230 training accuracy 78.311800| testing accuracy 77.845000
# iteration 160 / 300| training loss 0.772156| testing loss 0.779268 training accuracy 78.071600| testing accuracy 77.876000
# iteration 170 / 300| training loss 0.769471| testing loss 0.777318 training accuracy 77.883600| testing accuracy 77.921000
# iteration 180 / 300| training loss 0.760458| testing loss 0.770111 training accuracy 79.053600| testing accuracy 78.393000
# iteration 190 / 300| training loss 0.763081| testing loss 0.773768 training accuracy 78.434000| testing accuracy 77.690000
# iteration 200 / 300| training loss 0.760472| testing loss 0.772172 training accuracy 78.739600| testing accuracy 77.940000
# iteration 210 / 300| training loss 0.753586| testing loss 0.766012 training accuracy 78.842800| testing accuracy 78.633000
# iteration 220 / 300| training loss 0.756198| testing loss 0.767771 training accuracy 78.508000| testing accuracy 78.330000
# iteration 230 / 300| training loss 0.758260| testing loss 0.771199 training accuracy 79.046000| testing accuracy 78.207000
# iteration 240 / 300| training loss 0.749471| testing loss 0.765128 training accuracy 79.134200| testing accuracy 78.333000
# iteration 250 / 300| training loss 0.754370| testing loss 0.771801 training accuracy 78.872800| testing accuracy 78.262000
# iteration 260 / 300| training loss 0.747963| testing loss 0.766217 training accuracy 79.232400| testing accuracy 78.216000
# iteration 270 / 300| training loss 0.746901| testing loss 0.762680 training accuracy 79.552200| testing accuracy 78.373000
# iteration 280 / 300| training loss 0.741653| testing loss 0.759446 training accuracy 79.682200| testing accuracy 78.763000
# iteration 290 / 300| training loss 0.744888| testing loss 0.765596 training accuracy 79.673400| testing accuracy 78.252000

# %%
fig, axes = plt.subplots()
axes.plot(loss_history)  
axes.set_xlabel("epochs")
axes.set_ylabel("LOSS")
plt.show()
fig.savefig('LOSS.png',transparent=True)

# %%
fig, axes = plt.subplots()
axes.plot(loss_history_test)  
axes.set_xlabel("epochs")
axes.set_ylabel("LOSS")
plt.show()
fig.savefig('testing_loss.png',transparent=True)

# %%
fig, axes = plt.subplots() 
axes.plot(train_acc_history)  
axes.set_xlabel("epochs")
axes.set_ylabel("training accuracy")
plt.show()
fig.savefig('training_accuracy.png',transparent=True)

# %%
fig, axes = plt.subplots() 
axes.plot(val_acc_history)  
axes.set_xlabel("epochs")
axes.set_ylabel("testing accuracy")
plt.show()
fig.savefig('testing_accuracy.png',transparent=True)

# %%
fig, axes = plt.subplots() 
axes.plot(lr_history)  
axes.set_xlabel("epochs")
axes.set_ylabel("learning rate")
plt.show()
fig.savefig('learning rate.png',transparent=True)
